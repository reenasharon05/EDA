# %% [markdown]
# <a href="https://colab.research.google.com/github/reenasharon05/EDA/blob/EDA-sessions/session_8_19th_sep_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pp
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pp.read_excel("/content/book_sales.xlsx")

# %%
df
# Out:
#              genre                         sold by Release_date  \
# 0    genre fiction        HarperCollins Publishers   2012-01-03
# 1    genre fiction        HarperCollins Publishers   2012-02-07
# 2    genre fiction  Amazon Digital Services,  Inc.   2012-03-08
# 3          fiction             Hachette Book Group   2012-04-09
# 4    genre fiction         Penguin Group (USA) LLC   2012-05-10
# ..             ...                             ...          ...
# 194  genre fiction  Amazon Digital Services,  Inc.   2023-07-12
# 195  genre fiction                Random House LLC   2023-08-13
# 196  genre fiction  Amazon Digital Services,  Inc.   2023-09-14
# 197  genre fiction             Hachette Book Group   2023-10-15
# 198  genre fiction  Amazon Digital Services,  Inc.   2023-11-16
#
#      daily average.amazon revenue  daily average.author revenue  \
# 0                       6832.0000                     6832.0000
# 1                       2487.5000                     2487.5000
# ...

# %%
df.dtypes
# Out:
# genre                                      object
# sold by                                    object
# Release_date                       datetime64[ns]
# daily average.amazon revenue              float64
# daily average.author revenue              float64
# daily average.gross sales                 float64
# daily average.publisher revenue           float64
# daily average.units sold                    int64
# publisher.name                             object
# publisher.type                             object
# statistics.average rating                 float64
# statistics.sale price                     float64
# statistics.sales rank                       int64
# statistics.total reviews                    int64
# df_N                               datetime64[ns]
# dtype: object

# %%
#display duplicate record
df[df.duplicated()] #here no duplicate for this dataset
# Out:
# Empty DataFrame
# Columns: [genre, sold by, Release_date, daily average.amazon revenue, daily average.author revenue, daily average.gross sales, daily average.publisher revenue, daily average.units sold, publisher.name, publisher.type, statistics.average rating, statistics.sale price, statistics.sales rank, statistics.total reviews]
# Index: []

# %%
#if null is present in dataset
df.isnull().sum()
# Out:
# genre                              0
# sold by                            0
# Release_date                       0
# daily average.amazon revenue       0
# daily average.author revenue       0
# daily average.gross sales          0
# daily average.publisher revenue    0
# daily average.units sold           0
# publisher.name                     0
# publisher.type                     0
# statistics.average rating          0
# statistics.sale price              0
# statistics.sales rank              0
# statistics.total reviews           0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df[df['publisher.name'].isin(["Katherine Tegen Books"])]
# Out:
#            genre                   sold by Release_date  \
# 0  genre fiction  HarperCollins Publishers   2012-01-03
# 6  genre fiction  HarperCollins Publishers   2012-07-12
# 8  genre fiction  HarperCollins Publishers   2012-09-14
#
#    daily average.amazon revenue  daily average.author revenue  \
# 0                      6832.000                      6832.000
# 6                      5498.334                      5498.334
# 8                      5218.734                      5218.734
#
#    daily average.gross sales  daily average.publisher revenue  \
# 0                   34160.00                        20496.000
# 6                   27491.67                        16495.002
# 8                   26093.67                        15656.202
#
#    daily average.units sold         publisher.name publisher.type  \
# 0                      7000  Katherine Tegen Books       big five
# 6                      3933  Katherine Tegen Books       big five
# ...

# %%
#how to the year that has the highest no of temperature
df['df_N']=pp.to_datetime(df['Release_date'])
df
# Out:
#              genre                         sold by Release_date  \
# 0    genre fiction        HarperCollins Publishers   2012-01-03
# 1    genre fiction        HarperCollins Publishers   2012-02-07
# 2    genre fiction  Amazon Digital Services,  Inc.   2012-03-08
# 3          fiction             Hachette Book Group   2012-04-09
# 4    genre fiction         Penguin Group (USA) LLC   2012-05-10
# ..             ...                             ...          ...
# 194  genre fiction  Amazon Digital Services,  Inc.   2023-07-12
# 195  genre fiction                Random House LLC   2023-08-13
# 196  genre fiction  Amazon Digital Services,  Inc.   2023-09-14
# 197  genre fiction             Hachette Book Group   2023-10-15
# 198  genre fiction  Amazon Digital Services,  Inc.   2023-11-16
#
#      daily average.amazon revenue  daily average.author revenue  \
# 0                       6832.0000                     6832.0000
# 1                       2487.5000                     2487.5000
# ...

# %%
df['df_N'].dt.year.value_counts()
# Out:
# 2012    24
# 2013    24
# 2014    24
# 2015    24
# 2016    19
# 2021    13
# 2017    12
# 2018    12
# 2019    12
# 2020    12
# 2022    12
# 2023    11
# Name: df_N, dtype: int64

# %%
df['df_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#how many genre are there
df.groupby('genre').genre.count()
# Out:
# genre
# fiction            7
# genre fiction    174
# nonfiction        18
# Name: genre, dtype: int64

# %%
#countplot
sns.countplot(df["statistics.total reviews"])
# Out:
# <Axes: ylabel='count'>

# %%
df['year']=df['df_N'].dt.year #create new year column
df.head(2)
# Out:
#            genre                   sold by Release_date  \
# 0  genre fiction  HarperCollins Publishers   2012-01-03
# 1  genre fiction  HarperCollins Publishers   2012-02-07
#
#    daily average.amazon revenue  daily average.author revenue  \
# 0                        6832.0                        6832.0
# 1                        2487.5                        2487.5
#
#    daily average.gross sales  daily average.publisher revenue  \
# 0                    34160.0                          20496.0
# 1                    12437.5                           7462.5
#
#    daily average.units sold         publisher.name publisher.type  \
# 0                      7000  Katherine Tegen Books       big five
# 1                      6250  HarperCollins e-books       big five
#
#    statistics.average rating  statistics.sale price  statistics.sales rank  \
# 0                       4.57                   4.88                      1
# ...

# %%
#putting the category to a catory(genre)
df[(df['genre'] == 'fiction')&(df['year']==2012)]
# Out:
#       genre                  sold by Release_date  \
# 3   fiction      Hachette Book Group   2012-04-09
# 11  fiction  Penguin Group (USA) LLC   2012-12-17
#
#     daily average.amazon revenue  daily average.author revenue  \
# 3                         8250.0                        8250.0
# 11                        4312.8                        4312.8
#
#     daily average.gross sales  daily average.publisher revenue  \
# 3                     41250.0                          24750.0
# 11                    21564.0                          12938.4
#
#     daily average.units sold             publisher.name publisher.type  \
# 3                       5500  Little, Brown and Company       big five
# 11                      3600               Putnam Adult       big five
#
#     statistics.average rating  statistics.sale price  statistics.sales rank  \
# 3                        3.84                   7.50                      3
# ...

# %%
#to show the person who sold which genre of book
df[(df['genre'] == 'fiction') &(df['sold by'] == 'Hachette Book Group')]
# Out:
#      genre              sold by Release_date  daily average.amazon revenue  \
# 3  fiction  Hachette Book Group   2012-04-09                        8250.0
#
#    daily average.author revenue  daily average.gross sales  \
# 3                        8250.0                    41250.0
#
#    daily average.publisher revenue  daily average.units sold  \
# 3                          24750.0                      5500
#
#               publisher.name publisher.type  statistics.average rating  \
# 3  Little, Brown and Company       big five                       3.84
#
#    statistics.sale price  statistics.sales rank  statistics.total reviews  \
# 3                    7.5                      3                      3747
#
#         df_N  year
# 3 2012-04-09  2012

# %%
df['sold by'].value_counts()
# Out:
# Amazon Digital Services,  Inc.          114
# Random House LLC                         21
# Penguin Group (USA) LLC                  20
# HarperCollins Publishers                 16
# Hachette Book Group                      15
# Macmillan                                 8
# Simon and Schuster Digital Sales Inc      4
# HarperCollins Publishing                  1
# Name: sold by, dtype: int64
