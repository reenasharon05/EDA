# %% [markdown]
# <a href="https://colab.research.google.com/github/reenasharon05/EDA/blob/EDA-sessions/session_11_%2614.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pp
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Read the temperature dataset
df = pp.read_excel("/content/book_sales.xlsx")
df
# Out:
#             genre                         sold by  \
# 0   genre fiction        HarperCollins Publishers
# 1   genre fiction        HarperCollins Publishers
# 2   genre fiction  Amazon Digital Services,  Inc.
# 3         fiction             Hachette Book Group
# 4   genre fiction         Penguin Group (USA) LLC
# ..            ...                             ...
# 94  genre fiction                Random House LLC
# 95     nonfiction  Amazon Digital Services,  Inc.
# 96  genre fiction  Amazon Digital Services,  Inc.
# 97  genre fiction  Amazon Digital Services,  Inc.
# 98  genre fiction         Penguin Group (USA) LLC
#
#     daily average.amazon revenue  daily average.author revenue Release Date  \
# 0                       6832.000                      6832.000   2016-08-17
# 1                       2487.500                      2487.500   2016-09-18
# 2                       9559.000                      9559.000   2016-10-19
# ...

# %%
df.nunique()
# Out:
# genre                               3
# sold by                             7
# daily average.amazon revenue       96
# daily average.author revenue       96
# Release Date                       99
# daily average.publisher revenue    58
# daily average.units sold           81
# publisher.name                      3
# publisher.type                      5
# average rating                     65
# price                               6
# sales rank                         81
# total reviews                      95
# dtype: int64

# %%
sns.countplot(y='sold by',data=df)
plt.show()

# %%
#to know the count of each and every genre of books sold
df.groupby('genre').size()
# Out:
# genre
# fiction           3
# genre fiction    88
# nonfiction        8
# dtype: int64

# %%
sns.countplot(x='genre',data=df)
plt.title("Countplot of genre")
plt.xlabel("GENRE")
plt.ylabel("COUNT")
# Out:
# Text(0, 0.5, 'COUNT')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame and "statistics.total reviews" is the column name
#sns.set(style="darkgrid")
#plt.figure(figsize=(12, 6))

# Replace "df" with your DataFrame and "column_name" with the actual column name
sns.countplot(data=df, x="genre")



#plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-6668224fa9ea> in <cell line: 10>()
#       8 # Replace "df" with your DataFrame and "column_name" with the actual column name
#       9 sns.countplot(data=df, x="genre")
# ---> 10 plt.barch(gsize,count,color=['Orange','Gold','Crimson','c'])
#      11 plt.title("Countplot of genre")
#      12 plt.xlabel("GENRE")
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'barch'

# %%
gname=df.genre.unique()
gname
# Out:
# array(['genre fiction', 'fiction', 'nonfiction'], dtype=object)

# %%
gsize=df.groupby('genre').size()
gsize
# Out:
# genre
# fiction           3
# genre fiction    88
# nonfiction        8
# dtype: int64

# %%
gprice=df.price.unique()
gprice
# Out:
# array([100, 300, 299, 499, 350, 400])

# %%
gp=df.groupby('price').size()
gp
# Out:
# price
# 100    31
# 299    10
# 300    26
# 350    19
# 400     5
# 499     8
# dtype: int64

# %%
# Create the pie chart
plt.pie(gsize, labels=gname)
plt.show()

# %%
import numpy as np

df = pd.DataFrame({'statistics.sale price': np.random.randint(200, 1000, 172)})

low = np.sum(np.logical_and(df['statistics.sale price'] >= 200, df['statistics.sale price'] < 500))
medium = np.sum(np.logical_and(df['statistics.sale price'] >= 500, df['statistics.sale price'] < 700))
high = np.sum(df['statistics.sale price'] >= 700)

print(low)
print(medium)
print(high)
# Out:
# 69
# 41
# 62

# %%
np.max(df['price'])
# Out:
# 499

# %%
np.min(df['price'])
# Out:
# 100

# %%
var=pd.Series('price')
var
# Out:
# 0    price
# dtype: object

# %%
#import matplotlib.pyplot as plt
#import numpy as np

# Assuming you have a list of prices and publishers
#prices = [10.99, 20.99, 30.99, 40.99, 50.99, 60.99, 70.99, 80.99, 90.99, 100.99]
#publishers = ['Publisher A', 'Publisher B', 'Publisher C', 'Publisher D', 'Publisher E',
 #             'Publisher F', 'Publisher G', 'Publisher H', 'Publisher I', 'Publisher J']

# Assuming you have a list of books sold by publishers
#books_sold = [100, 200, 150, 300, 250, 180, 220, 120, 280, 350]

# Creating a bar chart
x = np.arange(len(gp))
width = 0.1

fig, ax = plt.subplots()
rects = ax.bar(x,'gp' , width)

# Adding labels and title
ax.set_xlabel('Prices')
ax.set_ylabel('GENRE TYPE')
ax.set_title('Prices vs. Number of Books Sold basesd on genre')

# Adding x-axis labels
ax.set_xticks(x)
ax.set_xticklabels(gprice)

# Rotating x-axis labels for better visibility
#plt.xticks(rotation=0)

# Displaying the count of books on top of each bar
for rect in rects:
    height = rect.get_height()
    ax.annotate(f'{height}', xy=(rect.get_x() + rect.get_width() / 2, height),
                xytext=(0, 3), textcoords="offset points",
                ha='center', va='bottom')

plt.show()

# %%
plt.xlabel('PRICE')
plt.ylabel("GENRE")
plt.bar(gp,gname)
# Out:
# <BarContainer object of 6 artists>

# %%
df.groupby(['genre'], as_index=False)['price'].mean()
# Out:
#            genre       price
# 0        fiction  250.000000
# 1  genre fiction  264.022727
# 2     nonfiction  318.500000

# %%
df.groupby(['genre'])['total reviews'].mean()
# Out:
# genre
# fiction          3540.000000
# genre fiction    2092.272727
# nonfiction        947.125000
# Name: total reviews, dtype: float64

# %%
df.groupby(['genre'],as_index=False)['total reviews'].mean()
# Out:
#            genre  total reviews
# 0        fiction    3540.000000
# 1  genre fiction    2092.272727
# 2     nonfiction     947.125000
